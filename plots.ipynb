# %%
# plot the csv data from top_AQI_rf.csv
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
data=pd.read_csv('./Results/top_AQI_rf.csv')
data.head()
# Out:
#    epsilon     k  size  error_full  error_coreset  error_coreset_smoothed
# 0   0.0045  2000  9153    0.304103       0.574034                0.627030
# 1   0.0079  2000  4150    0.304103       0.678782                0.738264
# 2   0.0160  2000  1979    0.304103       0.668754                0.665653
# 3   0.0165  2000  1960    0.304103       0.654522                0.729473
# 4   0.0194  2000  1668    0.304103       0.657143                0.636233

# %%
plt.figure(figsize=(10,6))
plt.plot(data['error_coreset'],label='RF')

plt.xlabel('size')
plt.legend()
plt.grid(True)
plt.show()
